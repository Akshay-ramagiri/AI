# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-ramagiri/AI/blob/main/19K41A0555_Gradient_Descent_Algorithm_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Assignment2.jpeg](data:image/jpeg;base64,...)

# %%
import numpy as np
x=np.random.uniform(-20,20)
eta=0.001
iter_max=500
iter=0
while iter<=iter_max:
  grad_x=4*(x*x*x)+6*x
  delx= -eta * grad_x
  x=x+delx
  iter=iter+1
obj=x*x*x*x + 3*(x*x) +10
print("Minimum value of function = ", round(obj) ,"at x =", round(x))
# Out:
# Minimum value of function =  10 at x = 0
