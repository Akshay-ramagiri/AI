# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-ramagiri/AI/blob/main/19K41A0555_Gradient_Descent_Algorithm_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Assignment3.jpeg](data:image/jpeg;base64,...)

# %%
import numpy as np
import math
x=np.random.uniform(-10,10)
y=np.random.uniform(-10,10)
eta=0.001
iter_max=1000
iter=1
while iter<iter_max:
  grad_x=6*x
  grad_y = -5*(math.exp(-y))
  delx = -eta * grad_x
  dely = -eta * grad_y
  x=x+delx
  y=y+dely
  iter=iter+1
obj =  3*(x*2) + 5*(math.exp(-y)) + 10
print("objective function has minimum value at ",obj," where x = ", round(x), " and y = ", round(y))
# Out:
# objective function has minimum value at  10.17063113689181  where x =  0  and y =  5
